# %% [markdown]
# # CS3780 August 25

# %% [markdown]
# ## What is Machine Learning?
# - Programs that improve with experience
# - A subfield of artificial intelligence
# - Input data and outputs, infer the program that must be running to produce that output, baesd on the data
